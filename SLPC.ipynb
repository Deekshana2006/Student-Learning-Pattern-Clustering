# %%
import pandas as pd
import numpy as np

data = {
    "Student_ID": [
        "S001", "S002", "S003", "S004", "S005",
        "S006", "S007", "S008", "S009", "S010",
        "S011", "S012", "S013", "S014", "S015",
        "S016", "S017", "S018", "S019", "S020",
        "S021", "S022", "S023", "S024", "S025",
        "S026", "S027", "S028", "S029", "S030"
    ],

    "Study_Hours": [
        2, 3, 5, 6, 1,
        4, 7, 2, 5, 8,
        3, 1, 6, 4, 2,
        7, 3, 5, 1, 6,
        4, 7, 2, 8, 3,
        6, 1, 5, 4, 7
    ],

    "Attendance": [
        65, 72, 85, 90, 55,
        78, 94, 68, 82, 96,
        70, 50, 88, 76, 60,
        91, 74, 84, 58, 87,
        80, 93, 62, 97, 71,
        89, 54, 86, 77, 92
    ],

    "Assignment_Score": [
        60, 68, 82, 88, 50,
        75, 92, 62, 80, 95,
        65, 45, 85, 73, 55,
        89, 70, 81, 52, 86,
        78, 91, 58, 96, 67,
        84, 48, 83, 74, 90
    ],

    "Quiz_Score": [
        58, 65, 80, 86, 48,
        72, 90, 60, 78, 93,
        63, 42, 84, 70, 52,
        88, 68, 79, 50, 83,
        75, 89, 55, 94, 64,
        82, 45, 81, 71, 87
    ],

    "Previous_GPA": [
        6.2, 6.8, 7.5, 8.1, 5.8,
        7.2, 8.7, 6.4, 7.6, 9.0,
        6.6, 5.5, 8.0, 7.1, 6.0,
        8.5, 6.9, 7.7, 5.9, 8.2,
        7.4, 8.6, 6.1, 9.1, 6.7,
        8.3, 5.7, 7.8, 7.0, 8.8
    ],

    "Online_Learning_Hours": [
        1, 2, 4, 5, 1,
        3, 6, 2, 4, 7,
        2, 0, 5, 3, 1,
        6, 2, 4, 1, 5,
        3, 6, 2, 7, 2,
        5, 1, 4, 3, 6
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Student_ID  Study_Hours  Attendance  Assignment_Score  Quiz_Score  \
# 0        S001            2          65                60          58
# 1        S002            3          72                68          65
# 2        S003            5          85                82          80
# 3        S004            6          90                88          86
# 4        S005            1          55                50          48
# 5        S006            4          78                75          72
# 6        S007            7          94                92          90
# 7        S008            2          68                62          60
# 8        S009            5          82                80          78
# 9        S010            8          96                95          93
# 10       S011            3          70                65          63
# 11       S012            1          50                45          42
# 12       S013            6          88                85          84
# 13       S014            4          76                73          70
# 14       S015            2          60                55          52
# 15       S016            7          91                89          88
# 16       S017            3          74                70          68
# 17       S018            5          84                81          79
# 18       S019            1          58                52          50
# 19       S020            6          87                86          83
# 20       S021            4          80                78          75
# 21       S022            7          93                91          89
# 22       S023            2          62                58          55
# 23       S024            8          97                96          94
# 24       S025            3          71                67          64
# 25       S026            6          89                84          82
# 26       S027            1          54                48          45
# 27       S028            5          86                83          81
# 28       S029            4          77                74          71
# 29       S030            7          92                90          87
#
#     Previous_GPA  Online_Learning_Hours
# 0            6.2                      1
# 1            6.8                      2
# 2            7.5                      4
# 3            8.1                      5
# 4            5.8                      1
# 5            7.2                      3
# 6            8.7                      6
# 7            6.4                      2
# 8            7.6                      4
# 9            9.0                      7
# 10           6.6                      2
# 11           5.5                      0
# 12           8.0                      5
# 13           7.1                      3
# 14           6.0                      1
# 15           8.5                      6
# 16           6.9                      2
# 17           7.7                      4
# 18           5.9                      1
# 19           8.2                      5
# 20           7.4                      3
# 21           8.6                      6
# 22           6.1                      2
# 23           9.1                      7
# 24           6.7                      2
# 25           8.3                      5
# 26           5.7                      1
# 27           7.8                      4
# 28           7.0                      3
# 29           8.8                      6
